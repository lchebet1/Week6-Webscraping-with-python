# %% [markdown]
# **Background Information**
#
# Together with a team of startup entrepreneurs, you decide to work on an idea that could change the way people search for jobs. You decide that job scraping could be the next big thing as there are actively many people looking for jobs in the country, in this case, Kenya.
# **Problem Statement**
#
# The problem is that there are many job listings which can not get visits for the target job seekers. While working in a team, your task as a data scientist for this project is to scrape for job titles and links and then put them in a single table that can be used by your team members to further build a job aggregator. You will be required to scrape for data from the following three technology webpages:
#
# ● PigiaMe: https://www.pigiame.co.ke/it-software-jobs
#
# ● MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
#
# ● KenyaJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offr e_secteur%3A133

# %% [markdown]
# # <font color='#2F4F4F'>AfterWork Data Science: Web Scraping with Python</font>

# %% [markdown]
# ## <font color='#2F4F4F'>Prerequisites</font>

# %%
# We first import the required libraries
# ---
#
import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage 
from urllib3.exceptions import InsecureRequestWarning
from urllib3 import disable_warnings

disable_warnings(InsecureRequestWarning)

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1: Obtaining our Data</font>

# %%
# PigiaMe: https://www.pigiame.co.ke/it-software-jobs
# ---
#
pigia_me = requests.get('https://www.pigiame.co.ke/it-software-jobs')
pigia_me
# Out:
# <Response [200]>

# %%
# MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
# ---
#
myjob_mag = requests.get('https://www.myjobmag.co.ke/jobs-by-field/information-technology')
myjob_mag
# Out:
# <Response [200]>

# %%
# KenyanJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133
# ---
kenyan_job = requests.get('https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133')
kenyan_job
# Out:
# <Response [200]>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2: Parsing</font>

# %%
# Parsing our document: pigia_me
# ---
#
pigia_me_soup= BeautifulSoup(pigia_me.text, "html.parser")

# %%
# Parsing our document: my_job_mag
# ---
#  
myjob_mag_soup = BeautifulSoup(myjob_mag.text,"html.parser")

# %%
# Parsing our document: kenyan_job
# ---
kenyan_job_soup= BeautifulSoup(kenyan_job.text, "html.parser")

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3: Extracting Required Elements</font>

# %%
# Each job is enclosed in 'div' class 'listings-cards__list-item'
pigia_me_job =  pigia_me_soup.find_all('div', class_= 'listings-cards__list-item')

# 1. Extracting job titles and links: pigia me
# ---

# # 1. Extracting job titles
#job_title_pigia_me  =  pigiame_job.find('div', class_='listing-card__header__title').get_text().replace('\n', '')


#Extract links

# links are in href of class 'listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder'
#link_pigia_me = pigiame_job.find('div', class_='listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder').a['href']


#create a list for link and title
pigia_me_link_title = []
pigia_me_link_url = []

# loop in through the pigiame website and colleact the link and title 

for p in pigia_me_job:
    # getting the title and links
    job_title_pigia_me  =  p.find('div', class_='listing-card__header__title').get_text().replace('\n', '')
    link_pigia_me = p.find('div', class_='listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder').a['href']

    #appending the title and links to the list
    # Then appending the text to our link_content list
    pigia_me_link_title.append(job_title_pigia_me)
      # Then appending the text to our link_url list
    pigia_me_link_url.append(link_pigia_me)
    
print(pigia_me_link_title)
['Bioinformatic and Software Developer', 'IT Sales - Cybersecurity & Cloud', 'Executive, Support & Services', 'Data Engineer', 'Software Development Trainer', 'Oracle Database Administrator', 'UI/UX & Frontend Developer – Limuru, Kenya', 'IT Sales - Cybersecurity & Cloud', 'Wordpress and Shopify Web Designer', 'Entry level Software Developer']
# 2. Extracting job titles: myjob_mag
# ---
# 
#jobtitle_myjob = soup_myjob.find('div', {'class':'listing-card__header__title'})[2].get_text()

# Extracting job titles
#Jobtilte is under <li class="job-list-li">
#<ul>
#<li class="job-logo">
#<a href="/jobs-at/cannon-general-insurance-k-ltd"><img src="/company_logo/86/61466Cannon General Insurance (K) Ltd.png" alt="Cannon General Insurance (K) Ltd logo" width="100%" height="auto" title="Cannon General Insurance (K) Ltd logo"></a>
#</li>
#<li class="job-info">
#<ul>
#<li class="mag-b">
#<h2><a href="/job/systems-developer-cannon-general-insurance-k-ltd">Systems Developer at Cannon General Insurance (K) Ltd</a></h2>
#</li>
#the job title and job link can be derived from 'li', class_ = 'mag-b'

myjob = myjob_mag_soup.find_all('li', class_ ='mag-b')

#create a list for link and title
myjob_link_title = []
myjob_link_url = []


#Extracting my job links and title

for link in myjob :
    myjob_link = 'https://www.myjobmag.co.ke' + link.find('h2').a['href']
    myjob_title = link.find('h2').a.text
    
     # Then appending the text to our link_content list
    myjob_link_title.append(myjob_title)

    # Then appending the text to our link_url list
    myjob_link_url.append(myjob_link)
    
    print(myjob_link_url)
# 3. Extracting job titles: kenya_job
# ---
#
# Each job is enclosed in 'div' class 'job-description-wrapper'
kenyanjob_job =  kenyan_job_soup.find_all('div', class_= 'job-description-wrapper')

# 1. Extracting job titles and links: 
# ---

# # 1. Extracting job titles . Titles are in calss 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title'.h5.a.text

#kenyanjob_jobtitle  = kenyanjob_job.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a.text

#Extract links

# links are in calss 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title'.h5.a['href']

#kenyanjob_joblink  = 'https://www.kenyajob.com' + kenyanjob_job.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a['href']


#create a list for link and title
kenyajob_link_title = []
kenyajob_link_url = []
# loop in through the pigiame website and colleact the link and title 

for k in kenyanjob_job :
    # getting the title and links
    
    kenyanjob_jobtitle  = k.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a.text
    kenyanjob_joblink  = 'https://www.kenyajob.com' + k.find('div', class_='col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title').h5.a['href']

    #appending the title and links to the list
    # Then appending the text to our link_content list
    kenyajob_link_title.append(kenyanjob_jobtitle)

    # Then appending the text to our link_url list
    kenyajob_link_url.append(kenyanjob_joblink)
    
print(kenyajob_link_title)
# Out:
# ['Data Scientist', 'AI Software Engineer', 'Data Analytics Engineer', 'Data Manager', 'Senior Software Engineer', 'Data Analyst - Kisumu', 'Data Analyst - Nakuru', 'Data Analyst - Eldoret', 'Data Analyst - Thika', 'Data Analyst - Mombasa']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko', 'https://www.myjobmag.co.ke/job/african-population-and-health-research-center-aphrc-african-population-and-health-research-center-aphrc']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko', 'https://www.myjobmag.co.ke/job/african-population-and-health-research-center-aphrc-african-population-and-health-research-center-aphrc', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-iii-3-posts-kericho-county']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko', 'https://www.myjobmag.co.ke/job/african-population-and-health-research-center-aphrc-african-population-and-health-research-center-aphrc', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-iii-3-posts-kericho-county', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-ii-6-posts-kericho-county']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko', 'https://www.myjobmag.co.ke/job/african-population-and-health-research-center-aphrc-african-population-and-health-research-center-aphrc', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-iii-3-posts-kericho-county', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-ii-6-posts-kericho-county', 'https://www.myjobmag.co.ke/job/thermo-fisher-scientific-thermo-fisher-scientific-1']
# ['https://www.myjobmag.co.ke/job/kenya-medical-research-kemri-kemya-medical-research-kemri-1', 'https://www.myjobmag.co.ke/job/micro-enterprises-support-programme-trust-mespt-micro-enterprises-support-programme-trust-mespt', 'https://www.myjobmag.co.ke/job/lead-android-developer-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/core-banking-application-developer-tezza-business-solutions-ltd-1', 'https://www.myjobmag.co.ke/job/tezza-business-solutions-ltd-tezza-business-solutions-ltd', 'https://www.myjobmag.co.ke/job/ts-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/sap-developer-dimension-data', 'https://www.myjobmag.co.ke/job/pc-lan-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/network-implementation-engineer-dimension-data', 'https://www.myjobmag.co.ke/job/client-solutions-architect-dimension-data', 'https://www.myjobmag.co.ke/job/head-ict-risk-ncba-group', 'https://www.myjobmag.co.ke/job/cbi-associate-united-nations-high-commissioner-for-refugees-unhcr', 'https://www.myjobmag.co.ke/job/full-stack-lead-engineer-wasoko', 'https://www.myjobmag.co.ke/job/african-population-and-health-research-center-aphrc-african-population-and-health-research-center-aphrc', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-iii-3-posts-kericho-county', 'https://www.myjobmag.co.ke/job/information-communication-technology-officer-ii-6-posts-kericho-county', 'https://www.myjobmag.co.ke/job/thermo-fisher-scientific-thermo-fisher-scientific-1', 'https://www.myjobmag.co.ke/job/standards-officers-information-science-1-post-kenya-bureau-of-standards']
# ['JAVA EE / JAVA 8 Developer with SQL Skills', 'Senior Freelance Web Designer', 'Accountant/Administrator', 'CCTV and Fire Alarms Systems Technician', 'CCTV and Fire Alarms Systems Technician', 'Information Technology Sales Specialist', 'AWS Cloud Architect (M/F)', 'AWS Solutions Architect (M/F)', 'AZURE Solutions Architect (M/F)', 'Cloud Architect (M/F)', 'Cloud Computing and Virtualization Engineer (M/F)', 'Cloud Engineer (M/F)', 'Cloud Microservices Architect (M/F)', 'Cloud System Administrator (M/F)', 'Cloud System Integrator (M/F)', 'Cyber Security Engineer (M/F)', 'DATASTAGE Architect (M/F)', 'GENESYS Architect (M/F)', 'Network Architect (M/F)', 'ANGULAR Developer (M/F)', 'DevOps Engineer (M/F)', 'DOTNET Developer (M/F)', 'IOS Developer (M/F)', 'JAVA Developer (M/F)', 'JAVA JEE Developer (M/F)']

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4: Saving our Data</font>

# %%
# Saving the scraped contents in a dataframe and preview our data
# ---
#
# Saving the scraped contents in a dataframe and preview our data
# ---
#pigiame dataframe
df_pigiame = pd.DataFrame({"Title": pigia_me_link_title , "Link": pigia_me_link_url})
df_pigiame.head()

#pigiame dataframe
df_myjob = pd.DataFrame({"Title":  myjob_link_title , "Link": myjob_link_url})


#pigiame dataframe
df_kenyajob = pd.DataFrame({"Title":kenyajob_link_title , "Link": kenyajob_link_url})
# concatenate the tables
df_job_search = pd.concat([df_pigiame, df_myjob,df_kenyajob], axis=0)

df_job_search
# Out:
#                                                 Title  \
# 0                                      Data Scientist
# 1                                AI Software Engineer
# 2                             Data Analytics Engineer
# 3                                        Data Manager
# 4                            Senior Software Engineer
# 5                               Data Analyst - Kisumu
# 6                               Data Analyst - Nakuru
# 7                              Data Analyst - Eldoret
# 8                                Data Analyst - Thika
# 9                              Data Analyst - Mombasa
# 0   Archivist (10 Positions) at Kenya Medical Rese...
# 1   Security Awareness Training and Simulated Phis...
# 2   Lead Android Developer at Tezza Business Solut...
# 3   Core-Banking Application Developer at Tezza Bu...
# 4     APEX Consultant at Tezza Business Solutions Ltd
# 5        TS Implementation Engineer at Dimension Data
# 6                     SAP Developer at Dimension Data
# 7                   PC LAN Engineer at Dimension Data
# 8   Network Implementation Engineer at Dimension Data
# 9        Client Solutions Architect at Dimension Data
# 10                       Head, ICT Risk at NCBA Group
# 11  CBI Associate at United Nations High Commissio...
# 12                 Full Stack Lead Engineer at Wasoko
# 13  AI Software Engineer at African Population And...
# 14  Information Communication Technology Officer I...
# 15  Information Communication Technology Officer I...
# 16  Sr Programmer Analyst - Early Phase at Thermo ...
# 17  Standards officers - Information Science (1 Po...
# 0          JAVA EE / JAVA 8 Developer with SQL Skills
# 1                       Senior Freelance Web Designer
# 2                            Accountant/Administrator
# 3             CCTV and Fire Alarms Systems Technician
# 4             CCTV and Fire Alarms Systems Technician
# 5             Information Technology Sales Specialist
# 6                           AWS Cloud Architect (M/F)
# 7                       AWS Solutions Architect (M/F)
# 8                     AZURE Solutions Architect (M/F)
# 9                               Cloud Architect (M/F)
# 10  Cloud Computing and Virtualization Engineer (M/F)
# 11                               Cloud Engineer (M/F)
# 12                Cloud Microservices Architect (M/F)
# 13                   Cloud System Administrator (M/F)
# 14                      Cloud System Integrator (M/F)
# 15                      Cyber Security Engineer (M/F)
# 16                          DATASTAGE Architect (M/F)
# 17                            GENESYS Architect (M/F)
# 18                            Network Architect (M/F)
# 19                            ANGULAR Developer (M/F)
# 20                              DevOps Engineer (M/F)
# 21                             DOTNET Developer (M/F)
# 22                                IOS Developer (M/F)
# 23                               JAVA Developer (M/F)
# 24                           JAVA JEE Developer (M/F)
#
#                                                  Link
# 0   https://www.pigiame.co.ke/listings/data-scient...
# 1   https://www.pigiame.co.ke/listings/ai-software...
# 2   https://www.pigiame.co.ke/listings/data-analyt...
# 3   https://www.pigiame.co.ke/listings/data-manage...
# 4   https://www.pigiame.co.ke/listings/senior-soft...
# 5   https://www.pigiame.co.ke/listings/data-analys...
# 6   https://www.pigiame.co.ke/listings/data-analys...
# 7   https://www.pigiame.co.ke/listings/data-analys...
# 8   https://www.pigiame.co.ke/listings/data-analys...
# 9   https://www.pigiame.co.ke/listings/data-analys...
# 0   https://www.myjobmag.co.ke/job/kenya-medical-r...
# 1   https://www.myjobmag.co.ke/job/micro-enterpris...
# 2   https://www.myjobmag.co.ke/job/lead-android-de...
# 3   https://www.myjobmag.co.ke/job/core-banking-ap...
# 4   https://www.myjobmag.co.ke/job/tezza-business-...
# 5   https://www.myjobmag.co.ke/job/ts-implementati...
# 6   https://www.myjobmag.co.ke/job/sap-developer-d...
# 7   https://www.myjobmag.co.ke/job/pc-lan-engineer...
# 8   https://www.myjobmag.co.ke/job/network-impleme...
# 9   https://www.myjobmag.co.ke/job/client-solution...
# 10  https://www.myjobmag.co.ke/job/head-ict-risk-n...
# 11  https://www.myjobmag.co.ke/job/cbi-associate-u...
# 12  https://www.myjobmag.co.ke/job/full-stack-lead...
# 13  https://www.myjobmag.co.ke/job/african-populat...
# 14  https://www.myjobmag.co.ke/job/information-com...
# 15  https://www.myjobmag.co.ke/job/information-com...
# 16  https://www.myjobmag.co.ke/job/thermo-fisher-s...
# 17  https://www.myjobmag.co.ke/job/standards-offic...
# 0   https://www.kenyajob.com/job-vacancies-kenya/j...
# 1   https://www.kenyajob.com/job-vacancies-kenya/s...
# 2   https://www.kenyajob.com/job-vacancies-kenya/a...
# 3   https://www.kenyajob.com/job-vacancies-kenya/c...
# 4   https://www.kenyajob.com/job-vacancies-kenya/c...
# 5   https://www.kenyajob.com/job-vacancies-kenya/i...
# 6   https://www.kenyajob.com/job-vacancies-kenya/a...
# 7   https://www.kenyajob.com/job-vacancies-kenya/a...
# 8   https://www.kenyajob.com/job-vacancies-kenya/a...
# 9   https://www.kenyajob.com/job-vacancies-kenya/c...
# 10  https://www.kenyajob.com/job-vacancies-kenya/c...
# 11  https://www.kenyajob.com/job-vacancies-kenya/c...
# 12  https://www.kenyajob.com/job-vacancies-kenya/c...
# 13  https://www.kenyajob.com/job-vacancies-kenya/c...
# 14  https://www.kenyajob.com/job-vacancies-kenya/c...
# 15  https://www.kenyajob.com/job-vacancies-kenya/c...
# 16  https://www.kenyajob.com/job-vacancies-kenya/d...
# 17  https://www.kenyajob.com/job-vacancies-kenya/g...
# 18  https://www.kenyajob.com/job-vacancies-kenya/n...
# 19  https://www.kenyajob.com/job-vacancies-kenya/a...
# 20  https://www.kenyajob.com/job-vacancies-kenya/d...
# 21  https://www.kenyajob.com/job-vacancies-kenya/d...
# 22  https://www.kenyajob.com/job-vacancies-kenya/i...
# 23  https://www.kenyajob.com/job-vacancies-kenya/j...
# 24  https://www.kenyajob.com/job-vacancies-kenya/j...
